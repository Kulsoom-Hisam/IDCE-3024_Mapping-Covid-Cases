# %%
#install required libraries
import pandas as pd
from matplotlib import pyplot as plt
  
plt.style.use('dark_background')

# %%
#import data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ee189ce1-0532-4e95-aa00-64021b35350a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee189ce1-0532-4e95-aa00-64021b35350a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid.csv to covid (1).csv

# %%
#read csv file
data=pd.read_csv('covid.csv')

daycount=data['Day']
FIN=data['Finland']
FRA=data['France']
DEU=data['Germany']
ITA=data['Italy']
ESP=data['Spain']
SWE=data['Sweden']

# %%
#change columns
plt.plot(daycount,FIN,label="Finland")
plt.plot(daycount,FRA,label="France")
plt.plot(daycount,DEU,label="Germany")
plt.plot(daycount,ITA,label="Italy")
plt.plot(daycount,ESP,label="Spain")
plt.plot(daycount,SWE,label="Sweden")

#avoid scientific notation
plt.ticklabel_format(style='plain') 

#add legend, title, labels
plt.legend()
plt.title('COVID-19 cases in European Countries')
plt.ylabel('Number of Infections')
plt.xlabel('Number of Days')

#show plot
plt.show()
